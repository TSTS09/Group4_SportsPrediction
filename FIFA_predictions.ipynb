# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.ensemble import RandomForestClassifier
#to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Loading the datasets to be used (both training and testing)
training_data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/A 2023/players_21.csv')
data1 = training_data.copy()

# %% [markdown]
# # 1. Data Pre-processing and Feature extraction process

# %% [markdown]
# ### Removing useless variables (Those with 30% missing values)

# %% [markdown]
# Removed columns containing URLs and players specific physical information since they do not affect the overall rating of the players but create an unexplained variance in the model, reducing the accuracy of the feature selection process

# %%
first_variables = training_data[['sofifa_id','overall', 'potential', 'age','weak_foot','skill_moves','international_reputation','work_rate','body_type']]
second_variables = training_data.loc[:, 'pace':'goalkeeping_speed']
training_data = pd.concat([first_variables,second_variables], axis=1)

# %% [markdown]
# Remove variables with more than 30% missing values (useless variables)

# %%
threshold = 0.30 *len(training_data)

# %%
training_data = training_data.dropna(thresh=threshold, axis =1)

# %% [markdown]
# #Exploratory Data Analysis(EDA)

# %% [markdown]
# Carrying out  exploratory data analysis (EDA) to better understand the data

# %%
#Viewing the first five element of the training data
training_data.head()
# Out:
#    sofifa_id  overall  potential  age  weak_foot  skill_moves  \
# 0     158023       93         93   33          4            4
# 1      20801       92         92   35          4            5
# 2     188545       91         91   31          4            4
# 3     190871       91         91   28          5            5
# 4     192985       91         91   29          5            4
#
#    international_reputation    work_rate body_type  pace  ...  \
# 0                         5   Medium/Low    Unique  85.0  ...
# 1                         5     High/Low    Unique  89.0  ...
# 2                         4  High/Medium    Unique  78.0  ...
# 3                         5  High/Medium    Unique  91.0  ...
# 4                         4    High/High    Unique  76.0  ...
#
#    mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                   75                   96                           32
# 1                   84                   95                           28
# 2                   88                   88                           35
# 3                   92                   93                           35
# 4                   84                   91                           68
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         35                        24                   6
# 1                         32                        24                   7
# 2                         42                        19                  15
# 3                         30                        29                   9
# 4                         65                        53                  15
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     6                   12                        8
# 3                     9                   15                       15
# 4                    13                    5                       10
#
#    goalkeeping_reflexes
# 0                     8
# 1                    11
# 2                    10
# 3                    11
# 4                    13
#
# [5 rows x 49 columns]

# %%
#Viewing the last five element of the training data
training_data.tail()
# Out:
#        sofifa_id  overall  potential  age  weak_foot  skill_moves  \
# 18939     257710       47         52   21          2            2
# 18940     257933       47         53   21          2            2
# 18941     257936       47         47   28          2            2
# 18942     258736       47         67   17          2            2
# 18943     258760       47         67   17          2            2
#
#        international_reputation      work_rate         body_type  pace  ...  \
# 18939                         1        Low/Low  Normal (170-185)  58.0  ...
# 18940                         1        Low/Low    Lean (170-185)  58.0  ...
# 18941                         1        Low/Low       Lean (185+)  65.0  ...
# 18942                         1  Medium/Medium    Lean (170-185)  70.0  ...
# 18943                         1  Medium/Medium  Normal (170-185)  64.0  ...
#
#        mentality_penalties  mentality_composure  defending_marking_awareness  \
# 18939                   35                   40                           45
# 18940                   35                   35                           43
# 18941                   36                   35                           38
# 18942                   50                   45                           18
# 18943                   36                   38                           32
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 18939                         56                        47
# 18940                         42                        53
# 18941                         43                        45
# 18942                         11                        13
# 18943                         44                        40
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 18939                  12                    13                    8
# 18940                   8                     8                   13
# 18941                   8                     5                   11
# 18942                  11                    13                    9
# 18943                  12                    10                    9
#
#        goalkeeping_positioning  goalkeeping_reflexes
# 18939                       14                     6
# 18940                       14                    10
# 18941                        5                     7
# 18942                        9                     6
# 18943                        6                     8
#
# [5 rows x 49 columns]

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Data columns (total 49 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   sofifa_id                    18944 non-null  int64
#  1   overall                      18944 non-null  int64
#  2   potential                    18944 non-null  int64
#  3   age                          18944 non-null  int64
#  4   weak_foot                    18944 non-null  int64
#  5   skill_moves                  18944 non-null  int64
#  6   international_reputation     18944 non-null  int64
#  7   work_rate                    18944 non-null  object
#  8   body_type                    18944 non-null  object
#  9   pace                         16861 non-null  float64
#  10  shooting                     16861 non-null  float64
#  11  passing                      16861 non-null  float64
#  12  dribbling                    16861 non-null  float64
#  13  defending                    16861 non-null  float64
#  14  physic                       16861 non-null  float64
#  15  attacking_crossing           18944 non-null  int64
#  16  attacking_finishing          18944 non-null  int64
#  17  attacking_heading_accuracy   18944 non-null  int64
#  18  attacking_short_passing      18944 non-null  int64
#  19  attacking_volleys            18944 non-null  int64
#  20  skill_dribbling              18944 non-null  int64
#  21  skill_curve                  18944 non-null  int64
#  22  skill_fk_accuracy            18944 non-null  int64
#  23  skill_long_passing           18944 non-null  int64
#  24  skill_ball_control           18944 non-null  int64
#  25  movement_acceleration        18944 non-null  int64
#  26  movement_sprint_speed        18944 non-null  int64
#  27  movement_agility             18944 non-null  int64
#  28  movement_reactions           18944 non-null  int64
#  29  movement_balance             18944 non-null  int64
#  30  power_shot_power             18944 non-null  int64
#  31  power_jumping                18944 non-null  int64
#  32  power_stamina                18944 non-null  int64
#  33  power_strength               18944 non-null  int64
#  34  power_long_shots             18944 non-null  int64
#  35  mentality_aggression         18944 non-null  int64
#  36  mentality_interceptions      18944 non-null  int64
#  37  mentality_positioning        18944 non-null  int64
#  38  mentality_vision             18944 non-null  int64
#  39  mentality_penalties          18944 non-null  int64
#  40  mentality_composure          18944 non-null  int64
#  41  defending_marking_awareness  18944 non-null  int64
#  42  defending_standing_tackle    18944 non-null  int64
#  43  defending_sliding_tackle     18944 non-null  int64
#  44  goalkeeping_diving           18944 non-null  int64
#  45  goalkeeping_handling         18944 non-null  int64
#  46  goalkeeping_kicking          18944 non-null  int64
#  47  goalkeeping_positioning      18944 non-null  int64
#  48  goalkeeping_reflexes         18944 non-null  int64
# dtypes: float64(6), int64(41), object(2)
# memory usage: 7.1+ MB

# %%
training_data.nunique() #Checking for the number of duplications in the columns
# Out:
# sofifa_id                      18944
# overall                           47
# potential                         48
# age                               29
# weak_foot                          5
# skill_moves                        5
# international_reputation           5
# work_rate                          9
# body_type                         10
# pace                              70
# shooting                          77
# passing                           68
# dribbling                         69
# defending                         77
# physic                            63
# attacking_crossing                89
# attacking_finishing               93
# attacking_heading_accuracy        89
# attacking_short_passing           86
# attacking_volleys                 88
# skill_dribbling                   91
# skill_curve                       91
# skill_fk_accuracy                 90
# skill_long_passing                86
# skill_ball_control                91
# movement_acceleration             85
# movement_sprint_speed             84
# movement_agility                  81
# movement_reactions                69
# movement_balance                  83
# power_shot_power                  76
# power_jumping                     75
# power_stamina                     85
# power_strength                    77
# power_long_shots                  91
# mentality_aggression              88
# mentality_interceptions           89
# mentality_positioning             94
# mentality_vision                  86
# mentality_penalties               87
# mentality_composure               85
# defending_marking_awareness       92
# defending_standing_tackle         87
# defending_sliding_tackle          85
# goalkeeping_diving                70
# goalkeeping_handling              71
# goalkeeping_kicking               80
# goalkeeping_positioning           77
# goalkeeping_reflexes              71
# dtype: int64

# %%
training_data.isnull().sum() # Getting the number of missing values in each columns
# Out:
# sofifa_id                         0
# overall                           0
# potential                         0
# age                               0
# weak_foot                         0
# skill_moves                       0
# international_reputation          0
# work_rate                         0
# body_type                         0
# pace                           2083
# shooting                       2083
# passing                        2083
# dribbling                      2083
# defending                      2083
# physic                         2083
# attacking_crossing                0
# attacking_finishing               0
# attacking_heading_accuracy        0
# attacking_short_passing           0
# attacking_volleys                 0
# skill_dribbling                   0
# skill_curve                       0
# skill_fk_accuracy                 0
# skill_long_passing                0
# skill_ball_control                0
# movement_acceleration             0
# movement_sprint_speed             0
# movement_agility                  0
# movement_reactions                0
# movement_balance                  0
# power_shot_power                  0
# power_jumping                     0
# power_stamina                     0
# power_strength                    0
# power_long_shots                  0
# mentality_aggression              0
# mentality_interceptions           0
# mentality_positioning             0
# mentality_vision                  0
# mentality_penalties               0
# mentality_composure               0
# defending_marking_awareness       0
# defending_standing_tackle         0
# defending_sliding_tackle          0
# goalkeeping_diving                0
# goalkeeping_handling              0
# goalkeeping_kicking               0
# goalkeeping_positioning           0
# goalkeeping_reflexes              0
# dtype: int64

# %%
((training_data.isnull().sum())/len(training_data))*100 # percentage of missing values in each column
# Out:
# sofifa_id                       0.000000
# overall                         0.000000
# potential                       0.000000
# age                             0.000000
# weak_foot                       0.000000
# skill_moves                     0.000000
# international_reputation        0.000000
# work_rate                       0.000000
# body_type                       0.000000
# pace                           10.995566
# shooting                       10.995566
# passing                        10.995566
# dribbling                      10.995566
# defending                      10.995566
# physic                         10.995566
# attacking_crossing              0.000000
# attacking_finishing             0.000000
# attacking_heading_accuracy      0.000000
# attacking_short_passing         0.000000
# attacking_volleys               0.000000
# skill_dribbling                 0.000000
# skill_curve                     0.000000
# skill_fk_accuracy               0.000000
# skill_long_passing              0.000000
# skill_ball_control              0.000000
# movement_acceleration           0.000000
# movement_sprint_speed           0.000000
# movement_agility                0.000000
# movement_reactions              0.000000
# movement_balance                0.000000
# power_shot_power                0.000000
# power_jumping                   0.000000
# power_stamina                   0.000000
# power_strength                  0.000000
# power_long_shots                0.000000
# mentality_aggression            0.000000
# mentality_interceptions         0.000000
# mentality_positioning           0.000000
# mentality_vision                0.000000
# mentality_penalties             0.000000
# mentality_composure             0.000000
# defending_marking_awareness     0.000000
# defending_standing_tackle       0.000000
# defending_sliding_tackle        0.000000
# goalkeeping_diving              0.000000
# goalkeeping_handling            0.000000
# goalkeeping_kicking             0.000000
# goalkeeping_positioning         0.000000
# goalkeeping_reflexes            0.000000
# dtype: float64

# %%
training_data.describe(include='all').T #Understanding the statistical description of the data
# Out:
#                                count unique               top  freq  \
# sofifa_id                    18944.0    NaN               NaN   NaN
# overall                      18944.0    NaN               NaN   NaN
# potential                    18944.0    NaN               NaN   NaN
# age                          18944.0    NaN               NaN   NaN
# weak_foot                    18944.0    NaN               NaN   NaN
# skill_moves                  18944.0    NaN               NaN   NaN
# international_reputation     18944.0    NaN               NaN   NaN
# work_rate                      18944      9     Medium/Medium  9980
# body_type                      18944     10  Normal (170-185)  6521
# pace                         16861.0    NaN               NaN   NaN
# shooting                     16861.0    NaN               NaN   NaN
# passing                      16861.0    NaN               NaN   NaN
# dribbling                    16861.0    NaN               NaN   NaN
# defending                    16861.0    NaN               NaN   NaN
# physic                       16861.0    NaN               NaN   NaN
# attacking_crossing           18944.0    NaN               NaN   NaN
# attacking_finishing          18944.0    NaN               NaN   NaN
# attacking_heading_accuracy   18944.0    NaN               NaN   NaN
# attacking_short_passing      18944.0    NaN               NaN   NaN
# attacking_volleys            18944.0    NaN               NaN   NaN
# skill_dribbling              18944.0    NaN               NaN   NaN
# skill_curve                  18944.0    NaN               NaN   NaN
# skill_fk_accuracy            18944.0    NaN               NaN   NaN
# skill_long_passing           18944.0    NaN               NaN   NaN
# skill_ball_control           18944.0    NaN               NaN   NaN
# movement_acceleration        18944.0    NaN               NaN   NaN
# movement_sprint_speed        18944.0    NaN               NaN   NaN
# movement_agility             18944.0    NaN               NaN   NaN
# movement_reactions           18944.0    NaN               NaN   NaN
# movement_balance             18944.0    NaN               NaN   NaN
# power_shot_power             18944.0    NaN               NaN   NaN
# power_jumping                18944.0    NaN               NaN   NaN
# power_stamina                18944.0    NaN               NaN   NaN
# power_strength               18944.0    NaN               NaN   NaN
# power_long_shots             18944.0    NaN               NaN   NaN
# mentality_aggression         18944.0    NaN               NaN   NaN
# mentality_interceptions      18944.0    NaN               NaN   NaN
# mentality_positioning        18944.0    NaN               NaN   NaN
# mentality_vision             18944.0    NaN               NaN   NaN
# mentality_penalties          18944.0    NaN               NaN   NaN
# mentality_composure          18944.0    NaN               NaN   NaN
# defending_marking_awareness  18944.0    NaN               NaN   NaN
# defending_standing_tackle    18944.0    NaN               NaN   NaN
# defending_sliding_tackle     18944.0    NaN               NaN   NaN
# goalkeeping_diving           18944.0    NaN               NaN   NaN
# goalkeeping_handling         18944.0    NaN               NaN   NaN
# goalkeeping_kicking          18944.0    NaN               NaN   NaN
# goalkeeping_positioning      18944.0    NaN               NaN   NaN
# goalkeeping_reflexes         18944.0    NaN               NaN   NaN
#
#                                       mean           std   min        25%  \
# sofifa_id                    226232.328917  27166.574284  41.0  210028.75
# overall                          65.677787      7.002278  47.0       61.0
# potential                        71.086729      6.109985  47.0       67.0
# age                              25.225823      4.697354  16.0       21.0
# weak_foot                         2.936603      0.667132   1.0        3.0
# skill_moves                       2.363017      0.766469   1.0        2.0
# international_reputation           1.09185      0.361841   1.0        1.0
# work_rate                              NaN           NaN   NaN        NaN
# body_type                              NaN           NaN   NaN        NaN
# pace                              67.66811     10.984862  25.0       62.0
# shooting                         52.274954     13.991421  16.0       42.0
# passing                          57.139434     10.273655  25.0       50.0
# dribbling                         62.45543     10.048706  25.0       57.0
# defending                        51.316292     16.405179  15.0       36.0
# physic                           64.458988      9.746706  28.0       58.0
# attacking_crossing               49.612859     18.153057   6.0       38.0
# attacking_finishing              45.796083     19.592269   3.0       30.0
# attacking_heading_accuracy       51.874578     17.321709   5.0       44.0
# attacking_short_passing          58.705448     14.572383   7.0       54.0
# attacking_volleys                42.669552     17.661569   3.0       30.0
# skill_dribbling                    55.5464     18.787112   5.0       49.0
# skill_curve                      47.187289     18.231204   4.0       35.0
# skill_fk_accuracy                42.356155     17.239561   5.0       31.0
# skill_long_passing                52.65303     15.205281   5.0       43.0
# skill_ball_control               58.482791      16.59804   5.0       54.0
# movement_acceleration            64.285103     14.926452  13.0       57.0
# movement_sprint_speed            64.326489     14.689422  12.0       57.0
# movement_agility                 63.333193     14.625189  14.0       55.0
# movement_reactions               61.609428      9.112954  24.0       56.0
# movement_balance                 63.918549     14.075215  12.0       56.0
# power_shot_power                 57.752798     13.330631  18.0       48.0
# power_jumping                     64.59053     11.888479  15.0       58.0
# power_stamina                     62.59602     15.878793  12.0       55.0
# power_strength                   64.742927     12.519775  16.0       57.0
# power_long_shots                 46.758763     19.305319   4.0       32.0
# mentality_aggression             55.488862     17.203045   9.0       44.0
# mentality_interceptions              46.25     20.738106   3.0       25.0
# mentality_positioning            50.255807     19.443738   2.0       40.0
# mentality_vision                 53.828231     13.724072   9.0       45.0
# mentality_penalties              48.050412     15.671721   6.0      38.75
# mentality_composure              57.978674      12.11839  12.0       50.0
# defending_marking_awareness      46.470017     20.169591   3.0       29.0
# defending_standing_tackle        47.581767     21.402461   5.0       27.0
# defending_sliding_tackle         45.546505     20.953997   4.0       24.0
# goalkeeping_diving               16.446052     17.577332   1.0        8.0
# goalkeeping_handling             16.236486      16.84548   1.0        8.0
# goalkeeping_kicking              16.103357     16.519399   1.0        8.0
# goalkeeping_positioning          16.225982     17.017341   1.0        8.0
# goalkeeping_reflexes             16.551309     17.878121   1.0        8.0
#
#                                   50%        75%       max
# sofifa_id                    232301.5  246745.75  258970.0
# overall                          66.0       70.0      93.0
# potential                        71.0       75.0      95.0
# age                              25.0       29.0      53.0
# weak_foot                         3.0        3.0       5.0
# skill_moves                       2.0        3.0       5.0
# international_reputation          1.0        1.0       5.0
# work_rate                         NaN        NaN       NaN
# body_type                         NaN        NaN       NaN
# pace                             68.0       75.0      96.0
# shooting                         54.0       63.0      93.0
# passing                          58.0       64.0      93.0
# dribbling                        64.0       69.0      95.0
# defending                        56.0       64.0      91.0
# physic                           66.0       72.0      91.0
# attacking_crossing               54.0       63.0      94.0
# attacking_finishing              49.0       62.0      95.0
# attacking_heading_accuracy       55.0       64.0      93.0
# attacking_short_passing          62.0       68.0      94.0
# attacking_volleys                44.0       56.0      90.0
# skill_dribbling                  61.0       68.0      96.0
# skill_curve                      48.0       61.0      94.0
# skill_fk_accuracy                41.0       55.0      94.0
# skill_long_passing               56.0       64.0      93.0
# skill_ball_control               63.0       69.0      96.0
# movement_acceleration            67.0       74.0      97.0
# movement_sprint_speed            67.0       74.0      96.0
# movement_agility                 66.0       74.0      96.0
# movement_reactions               62.0       68.0      95.0
# movement_balance                 66.0       74.0      97.0
# power_shot_power                 59.0       68.0      95.0
# power_jumping                    65.0       73.0      95.0
# power_stamina                    66.0       73.0      97.0
# power_strength                   66.0       74.0      97.0
# power_long_shots                 51.0       62.0      94.0
# mentality_aggression             58.0       68.0      96.0
# mentality_interceptions          52.0       64.0      91.0
# mentality_positioning            55.0       64.0      95.0
# mentality_vision                 55.0       64.0      95.0
# mentality_penalties              49.0       60.0      92.0
# mentality_composure              59.0       66.0      96.0
# defending_marking_awareness      52.0       63.0      94.0
# defending_standing_tackle        55.0       65.0      93.0
# defending_sliding_tackle         52.0       63.0      90.0
# goalkeeping_diving               11.0       14.0      90.0
# goalkeeping_handling             11.0       14.0      92.0
# goalkeeping_kicking              11.0       14.0      93.0
# goalkeeping_positioning          11.0       14.0      91.0
# goalkeeping_reflexes             11.0       14.0      90.0

# %%
training_data.dtypes   #viewing the data types of the columns
# Out:
# sofifa_id                        int64
# overall                          int64
# potential                        int64
# age                              int64
# weak_foot                        int64
# skill_moves                      int64
# international_reputation         int64
# work_rate                       object
# body_type                       object
# pace                           float64
# shooting                       float64
# passing                        float64
# dribbling                      float64
# defending                      float64
# physic                         float64
# attacking_crossing               int64
# attacking_finishing              int64
# attacking_heading_accuracy       int64
# attacking_short_passing          int64
# attacking_volleys                int64
# skill_dribbling                  int64
# skill_curve                      int64
# skill_fk_accuracy                int64
# skill_long_passing               int64
# skill_ball_control               int64
# movement_acceleration            int64
# movement_sprint_speed            int64
# movement_agility                 int64
# movement_reactions               int64
# movement_balance                 int64
# power_shot_power                 int64
# power_jumping                    int64
# power_stamina                    int64
# power_strength                   int64
# power_long_shots                 int64
# mentality_aggression             int64
# mentality_interceptions          int64
# mentality_positioning            int64
# mentality_vision                 int64
# mentality_penalties              int64
# mentality_composure              int64
# defending_marking_awareness      int64
# defending_standing_tackle        int64
# defending_sliding_tackle         int64
# goalkeeping_diving               int64
# goalkeeping_handling             int64
# goalkeeping_kicking              int64
# goalkeeping_positioning          int64
# goalkeeping_reflexes             int64
# dtype: object

# %% [markdown]
# ### Understanding how strongly different variables (columns in the DataFrame) are related to each other.

# %%
correlation_matrix= training_data.corr()

# %%
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %%
#Displays the summary of the set of data values of the overall column
training_data[['overall']].boxplot()
# Out:
# <Axes: >

# %%
#Generating a plot that shows the frequency or count of each unique value in the 'overall' column
sns.countplot(x=training_data['overall'])
# Out:
# <Axes: xlabel='overall', ylabel='count'>

# %% [markdown]
#  Performing a t-test to assess whether there is a statistically significant difference between the 'overall' and 'potential' data in the training_data. The t-statistic of -80.11 indicates a substantial difference between the groups being compared. The p-value of 0.0 suggests that this difference is highly unlikely to have occurred by chance, leading to the rejection of the null hypothesis and indicating a significant difference between the groups.

# %%
from scipy.stats import ttest_ind

group_1 = training_data['overall']
group_2 = training_data['potential']

t_stat, p_value = ttest_ind(group_1, group_2)

print(f"t-statistic: {t_stat}")
rounded_p_value = round(p_value, 5)
print(f"P-value: {rounded_p_value}")

if rounded_p_value < 0.05:
    print("Reject the null hypothesis (significant difference between groups).")
else:
    print("Fail to reject the null hypothesis (no significant difference between groups).")
# Out:
# t-statistic: -80.10917765817972
# P-value: 0.0
# Reject the null hypothesis (significant difference between groups).

# %% [markdown]
# ### Splitting numerical and categorical variables

# %%
y = training_data['overall']
training_data.drop('overall', axis=1,inplace=True)

# %% [markdown]
# Separating the numerical and categorical variables

# %%
numerical_columns = training_data.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = training_data.select_dtypes(include=['object']).columns

# %%
categorical_var = training_data[categorical_columns]
numerical_var = training_data[numerical_columns]

# %%
numerical_var
# Out:
#        sofifa_id  potential  age  weak_foot  skill_moves  \
# 0         158023         93   33          4            4
# 1          20801         92   35          4            5
# 2         188545         91   31          4            4
# 3         190871         91   28          5            5
# 4         192985         91   29          5            4
# ...          ...        ...  ...        ...          ...
# 18939     257710         52   21          2            2
# 18940     257933         53   21          2            2
# 18941     257936         47   28          2            2
# 18942     258736         67   17          2            2
# 18943     258760         67   17          2            2
#
#        international_reputation  pace  shooting  passing  dribbling  ...  \
# 0                             5  85.0      92.0     91.0       95.0  ...
# 1                             5  89.0      93.0     81.0       89.0  ...
# 2                             4  78.0      91.0     78.0       85.0  ...
# 3                             5  91.0      85.0     86.0       94.0  ...
# 4                             4  76.0      86.0     93.0       88.0  ...
# ...                         ...   ...       ...      ...        ...  ...
# 18939                         1  58.0      23.0     26.0       27.0  ...
# 18940                         1  58.0      32.0     49.0       47.0  ...
# 18941                         1  65.0      37.0     49.0       46.0  ...
# 18942                         1  70.0      46.0     40.0       53.0  ...
# 18943                         1  64.0      40.0     48.0       49.0  ...
#
#        mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                       75                   96                           32
# 1                       84                   95                           28
# 2                       88                   88                           35
# 3                       92                   93                           35
# 4                       84                   91                           68
# ...                    ...                  ...                          ...
# 18939                   35                   40                           45
# 18940                   35                   35                           43
# 18941                   36                   35                           38
# 18942                   50                   45                           18
# 18943                   36                   38                           32
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                             35                        24
# 1                             32                        24
# 2                             42                        19
# 3                             30                        29
# 4                             65                        53
# ...                          ...                       ...
# 18939                         56                        47
# 18940                         42                        53
# 18941                         43                        45
# 18942                         11                        13
# 18943                         44                        40
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                       6                    11                   15
# 1                       7                    11                   15
# 2                      15                     6                   12
# 3                       9                     9                   15
# 4                      15                    13                    5
# ...                   ...                   ...                  ...
# 18939                  12                    13                    8
# 18940                   8                     8                   13
# 18941                   8                     5                   11
# 18942                  11                    13                    9
# 18943                  12                    10                    9
#
#        goalkeeping_positioning  goalkeeping_reflexes
# 0                           14                     8
# 1                           14                    11
# 2                            8                    10
# 3                           15                    11
# 4                           10                    13
# ...                        ...                   ...
# 18939                       14                     6
# 18940                       14                    10
# 18941                        5                     7
# 18942                        9                     6
# 18943                        6                     8
#
# [18944 rows x 46 columns]

# %%
categorical_var
# Out:
#            work_rate         body_type
# 0         Medium/Low            Unique
# 1           High/Low            Unique
# 2        High/Medium            Unique
# 3        High/Medium            Unique
# 4          High/High            Unique
# ...              ...               ...
# 18939        Low/Low  Normal (170-185)
# 18940        Low/Low    Lean (170-185)
# 18941        Low/Low       Lean (185+)
# 18942  Medium/Medium    Lean (170-185)
# 18943  Medium/Medium  Normal (170-185)
#
# [18944 rows x 2 columns]

# %% [markdown]
# ### KNN imputation of numerical variables

# %%
knn_imputer = KNNImputer(n_neighbors=8)
numerical_var_imputed = knn_imputer.fit_transform(numerical_var)
numerical_columns = list(numerical_var.columns)
numerical_var_imputed = pd.DataFrame(numerical_var_imputed, columns=numerical_columns)

# %% [markdown]
# ### Imputation and Encoding categorical variables

# %% [markdown]
# Imputing the the NaN of the catagorical variabe with simple imputer using the most frequent elements in the columns and encoding the categorical variable with factorize function

# %%
categorical_imputer = SimpleImputer(strategy='most_frequent')
categorical_var_imputed = categorical_imputer.fit_transform(categorical_var)

# %%
categorical_columns = list(categorical_var.columns)
Categorical_var_2 = pd.DataFrame(categorical_var_imputed, columns = categorical_columns)

# %%
columns_to_encode = categorical_var.loc[:, 'work_rate':'body_type']

# %%
categorical_var[columns_to_encode.columns] = columns_to_encode.apply(lambda x: pd.factorize(x)[0])

# %%
Categorical_var_2= pd.DataFrame(categorical_var[columns_to_encode.columns],)

# %%
 Categorical_var_2
# Out:
#        work_rate  body_type
# 0              0          0
# 1              1          0
# 2              2          0
# 3              2          0
# 4              3          0
# ...          ...        ...
# 18939          8          1
# 18940          8          2
# 18941          8          4
# 18942          4          2
# 18943          4          1
#
# [18944 rows x 2 columns]

# %% [markdown]
# ### Joining back the preprocessed numerical and categorical datasets to form a complete dataset with relevant columns

# %%
clean_data = pd.concat([numerical_var_imputed, Categorical_var_2], axis=1)
clean_data
# Out:
#        sofifa_id  potential   age  weak_foot  skill_moves  \
# 0       158023.0       93.0  33.0        4.0          4.0
# 1        20801.0       92.0  35.0        4.0          5.0
# 2       188545.0       91.0  31.0        4.0          4.0
# 3       190871.0       91.0  28.0        5.0          5.0
# 4       192985.0       91.0  29.0        5.0          4.0
# ...          ...        ...   ...        ...          ...
# 18939   257710.0       52.0  21.0        2.0          2.0
# 18940   257933.0       53.0  21.0        2.0          2.0
# 18941   257936.0       47.0  28.0        2.0          2.0
# 18942   258736.0       67.0  17.0        2.0          2.0
# 18943   258760.0       67.0  17.0        2.0          2.0
#
#        international_reputation  pace  shooting  passing  dribbling  ...  \
# 0                           5.0  85.0      92.0     91.0       95.0  ...
# 1                           5.0  89.0      93.0     81.0       89.0  ...
# 2                           4.0  78.0      91.0     78.0       85.0  ...
# 3                           5.0  91.0      85.0     86.0       94.0  ...
# 4                           4.0  76.0      86.0     93.0       88.0  ...
# ...                         ...   ...       ...      ...        ...  ...
# 18939                       1.0  58.0      23.0     26.0       27.0  ...
# 18940                       1.0  58.0      32.0     49.0       47.0  ...
# 18941                       1.0  65.0      37.0     49.0       46.0  ...
# 18942                       1.0  70.0      46.0     40.0       53.0  ...
# 18943                       1.0  64.0      40.0     48.0       49.0  ...
#
#        defending_marking_awareness  defending_standing_tackle  \
# 0                             32.0                       35.0
# 1                             28.0                       32.0
# 2                             35.0                       42.0
# 3                             35.0                       30.0
# 4                             68.0                       65.0
# ...                            ...                        ...
# 18939                         45.0                       56.0
# 18940                         43.0                       42.0
# 18941                         38.0                       43.0
# 18942                         18.0                       11.0
# 18943                         32.0                       44.0
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                          24.0                 6.0                  11.0
# 1                          24.0                 7.0                  11.0
# 2                          19.0                15.0                   6.0
# 3                          29.0                 9.0                   9.0
# 4                          53.0                15.0                  13.0
# ...                         ...                 ...                   ...
# 18939                      47.0                12.0                  13.0
# 18940                      53.0                 8.0                   8.0
# 18941                      45.0                 8.0                   5.0
# 18942                      13.0                11.0                  13.0
# 18943                      40.0                12.0                  10.0
#
#        goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes  \
# 0                     15.0                     14.0                   8.0
# 1                     15.0                     14.0                  11.0
# 2                     12.0                      8.0                  10.0
# 3                     15.0                     15.0                  11.0
# 4                      5.0                     10.0                  13.0
# ...                    ...                      ...                   ...
# 18939                  8.0                     14.0                   6.0
# 18940                 13.0                     14.0                  10.0
# 18941                 11.0                      5.0                   7.0
# 18942                  9.0                      9.0                   6.0
# 18943                  9.0                      6.0                   8.0
#
#        work_rate  body_type
# 0              0          0
# 1              1          0
# 2              2          0
# 3              2          0
# 4              3          0
# ...          ...        ...
# 18939          8          1
# 18940          8          2
# 18941          8          4
# 18942          4          2
# 18943          4          1
#
# [18944 rows x 48 columns]

# %% [markdown]
# # 2. Feature Engineering

# %% [markdown]
# #Determining feature importance

# %% [markdown]
# ### Classifying features using the Random Forest Classifier to sort the most important

# %%
#Using RandomForestClassifier
model = RandomForestClassifier()
model.fit(clean_data, y)  # Train the model

# Access feature importances
feature_importances = model.feature_importances_

# %%
#Visualizing the feature importance
plt.figure(figsize=(10, 6))
plt.bar(range(len(feature_importances)), feature_importances, tick_label=clean_data.columns)
plt.xlabel('Features')
plt.ylabel('Feature Importance')
plt.title('Feature Importance in RandomForest Model')
plt.xticks(rotation='vertical')
plt.show()

# %%
#Ranking the features based on the results above
feature_names = clean_data.columns # Replace with your feature names

# Sort feature importance in descending order
indices = np.argsort(feature_importances)[::-1]

# Print feature ranking
print("Feature ranking based on Random Forest Classifier:")
for f in range(len(feature_names)):
    print(f"{f + 1}. {feature_names[indices[f]]}: {feature_importances[indices[f]]}")
# Out:
# Feature ranking based on Random Forest Classifier:
# 1. potential: 0.0680251978774962
# 2. movement_reactions: 0.035062148412296296
# 3. defending: 0.029787262915554728
# 4. skill_ball_control: 0.027885519437439638
# 5. attacking_crossing: 0.024689721111467673
# 6. sofifa_id: 0.024559044643660623
# 7. dribbling: 0.024348557231098526
# 8. mentality_positioning: 0.02407930018752662
# 9. defending_standing_tackle: 0.023437980517623358
# 10. mentality_interceptions: 0.0232124844135634
# 11. age: 0.02295812480883299
# 12. defending_marking_awareness: 0.02285189988204174
# 13. defending_sliding_tackle: 0.022761912292070297
# 14. physic: 0.02266152621189367
# 15. shooting: 0.022386890557944364
# 16. mentality_composure: 0.02227744003775002
# 17. attacking_short_passing: 0.022110013433340233
# 18. power_stamina: 0.02198160729426664
# 19. skill_dribbling: 0.02175320088168602
# 20. passing: 0.021010083045065252
# 21. attacking_heading_accuracy: 0.020988330322947796
# 22. goalkeeping_positioning: 0.020782821489928462
# 23. power_shot_power: 0.020717819349991947
# 24. mentality_aggression: 0.020707242076105234
# 25. pace: 0.020520691138918155
# 26. movement_sprint_speed: 0.02051299787208441
# 27. attacking_finishing: 0.020315572008873968
# 28. movement_acceleration: 0.01983489240267314
# 29. goalkeeping_diving: 0.019810396756348058
# 30. power_strength: 0.019780064601026194
# 31. goalkeeping_reflexes: 0.019648409117762496
# 32. power_jumping: 0.01938416783884516
# 33. mentality_vision: 0.01936477156286533
# 34. goalkeeping_handling: 0.01890102340662268
# 35. skill_long_passing: 0.01868263208213462
# 36. movement_balance: 0.0184391216767278
# 37. power_long_shots: 0.018423113898670542
# 38. attacking_volleys: 0.018380189036254282
# 39. movement_agility: 0.01836027530497914
# 40. skill_curve: 0.01815023098226626
# 41. mentality_penalties: 0.017947073788680386
# 42. skill_fk_accuracy: 0.017852179054992694
# 43. goalkeeping_kicking: 0.016303700990731695
# 44. body_type: 0.00980991826272867
# 45. work_rate: 0.008011564480843841
# 46. weak_foot: 0.005823506454987963
# 47. skill_moves: 0.0032421498304599796
# 48. international_reputation: 0.001465229017930786

# %% [markdown]
# ###Analysing feature importance based on correlation matrix with target variable 'overall'

# %%
correlation = clean_data.corrwith(y).abs()
sorted_correlation = correlation.sort_values(ascending=False)
sorted_correlation
# Out:
# movement_reactions             0.867234
# mentality_composure            0.705252
# passing                        0.678161
# potential                      0.636366
# dribbling                      0.609726
# power_shot_power               0.558372
# physic                         0.525042
# mentality_vision               0.509087
# attacking_short_passing        0.502191
# skill_long_passing             0.487147
# sofifa_id                      0.486575
# shooting                       0.479750
# age                            0.468197
# skill_ball_control             0.449372
# international_reputation       0.440987
# skill_curve                    0.420495
# attacking_crossing             0.410530
# power_long_shots               0.407525
# mentality_aggression           0.401920
# skill_fk_accuracy              0.385617
# power_stamina                  0.381869
# skill_moves                    0.381369
# skill_dribbling                0.378455
# attacking_volleys              0.374330
# power_strength                 0.358049
# mentality_positioning          0.354239
# defending                      0.351496
# mentality_penalties            0.328198
# attacking_heading_accuracy     0.327239
# attacking_finishing            0.325413
# defending_marking_awareness    0.320986
# mentality_interceptions        0.320162
# power_jumping                  0.282440
# movement_agility               0.279889
# defending_standing_tackle      0.260325
# defending_sliding_tackle       0.232392
# weak_foot                      0.222814
# movement_sprint_speed          0.215745
# movement_acceleration          0.206962
# pace                           0.189680
# movement_balance               0.128349
# work_rate                      0.097529
# goalkeeping_positioning        0.012274
# body_type                      0.004861
# goalkeeping_reflexes           0.004052
# goalkeeping_handling           0.003454
# goalkeeping_diving             0.003128
# goalkeeping_kicking            0.000512
# dtype: float64

# %% [markdown]
# ###Selecting top 35 features from correlation to create a subset of the data based on their relevance to the overal rating

# %%
N = 35
top_features = sorted_correlation.index[:N]
feature_subset = clean_data[top_features]
feature_subset
# Out:
#        movement_reactions  mentality_composure  passing  potential  dribbling  \
# 0                    94.0                 96.0     91.0       93.0       95.0
# 1                    95.0                 95.0     81.0       92.0       89.0
# 2                    93.0                 88.0     78.0       91.0       85.0
# 3                    91.0                 93.0     86.0       91.0       94.0
# 4                    91.0                 91.0     93.0       91.0       88.0
# ...                   ...                  ...      ...        ...        ...
# 18939                48.0                 40.0     26.0       52.0       27.0
# 18940                50.0                 35.0     49.0       53.0       47.0
# 18941                44.0                 35.0     49.0       47.0       46.0
# 18942                53.0                 45.0     40.0       67.0       53.0
# 18943                51.0                 38.0     48.0       67.0       49.0
#
#        power_shot_power  physic  mentality_vision  attacking_short_passing  \
# 0                  86.0    65.0              95.0                     91.0
# 1                  94.0    77.0              82.0                     82.0
# 2                  89.0    82.0              79.0                     84.0
# 3                  80.0    59.0              90.0                     87.0
# 4                  91.0    78.0              94.0                     94.0
# ...                 ...     ...               ...                      ...
# 18939              35.0    48.0              25.0                     31.0
# 18940              38.0    48.0              53.0                     55.0
# 18941              49.0    59.0              44.0                     56.0
# 18942              50.0    40.0              49.0                     45.0
# 18943              48.0    45.0              47.0                     56.0
#
#        skill_long_passing  ...  mentality_positioning  defending  \
# 0                    91.0  ...                   93.0       38.0
# 1                    77.0  ...                   95.0       35.0
# 2                    70.0  ...                   94.0       43.0
# 3                    81.0  ...                   87.0       36.0
# 4                    93.0  ...                   88.0       64.0
# ...                   ...  ...                    ...        ...
# 18939                25.0  ...                   25.0       50.0
# 18940                50.0  ...                   32.0       43.0
# 18941                56.0  ...                   48.0       40.0
# 18942                37.0  ...                   43.0       16.0
# 18943                50.0  ...                   47.0       35.0
#
#        mentality_penalties  attacking_heading_accuracy  attacking_finishing  \
# 0                     75.0                        70.0                 95.0
# 1                     84.0                        90.0                 95.0
# 2                     88.0                        85.0                 94.0
# 3                     92.0                        62.0                 87.0
# 4                     84.0                        55.0                 82.0
# ...                    ...                         ...                  ...
# 18939                 35.0                        45.0                 16.0
# 18940                 35.0                        42.0                 30.0
# 18941                 36.0                        44.0                 32.0
# 18942                 50.0                        36.0                 47.0
# 18943                 36.0                        40.0                 42.0
#
#        defending_marking_awareness  mentality_interceptions  power_jumping  \
# 0                             32.0                     40.0           68.0
# 1                             28.0                     29.0           95.0
# 2                             35.0                     49.0           84.0
# 3                             35.0                     36.0           62.0
# 4                             68.0                     66.0           63.0
# ...                            ...                      ...            ...
# 18939                         45.0                     50.0           65.0
# 18940                         43.0                     42.0           53.0
# 18941                         38.0                     35.0           59.0
# 18942                         18.0                     11.0           50.0
# 18943                         32.0                     23.0           58.0
#
#        movement_agility  defending_standing_tackle
# 0                  91.0                       35.0
# 1                  87.0                       32.0
# 2                  77.0                       42.0
# 3                  96.0                       30.0
# 4                  78.0                       65.0
# ...                 ...                        ...
# 18939              45.0                       56.0
# 18940              50.0                       42.0
# 18941              56.0                       43.0
# 18942              67.0                       11.0
# 18943              61.0                       44.0
#
# [18944 rows x 35 columns]

# %% [markdown]
# #

# %% [markdown]
# ###Selecting the best 10 features using PCA from the model created from the correlation matrix

# %%
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, f_regression
import pandas as pd

# Perform feature selection to determine the best features (e.g., using SelectKBest with f_regression)
k_best = SelectKBest(score_func=f_regression, k=10)
best_features = k_best.fit_transform(feature_subset, y)

# Get the column names of the best features
best_feature_indices = k_best.get_support(indices=True)
best_feature_names = feature_subset.columns[best_feature_indices]

# %%
n_components = 10
pca = PCA(n_components=n_components)
new_data = pca.fit_transform(best_features)
pca_columns = list(feature_subset[best_feature_names].columns)
newX = pd.DataFrame(new_data, columns = pca_columns)

# %%
#The final set of independent variables withh highest relevance to the overall ratings
newX
# Out:
#        movement_reactions  mentality_composure    passing  potential  \
# 0               98.657830            10.415956  -2.043653 -18.840934
# 1               82.052231            24.614027  12.276008  -8.935557
# 2               72.408010            22.643721  15.753501  -8.159578
# 3               84.365146            11.002660  -6.140448 -21.249898
# 4               99.353464             9.502512   6.686580  -9.030707
# ...                   ...                  ...        ...        ...
# 18939          -74.261242            -8.184033  -1.722268   8.467034
# 18940          -29.103742           -21.191972 -18.149455   1.701668
# 18941          -27.006716           -20.984384  -9.419344  18.065507
# 18942          -33.234550            -0.305439 -20.539540   0.605514
# 18943          -25.167595           -14.836725 -17.107289   5.449910
#
#        dribbling  power_shot_power    physic  mentality_vision  \
# 0      -6.488965          4.658091 -6.489780         -5.714153
# 1      -8.660088          4.873385 -5.593733         -3.464687
# 2      -5.640659          6.088448 -5.180526          4.646937
# 3     -11.000090          3.168413 -4.402355         -3.515472
# 4       2.947370          6.089799 -7.049486         -2.069770
# ...          ...               ...       ...               ...
# 18939  -5.440664        -13.634771 -3.877162         -6.674713
# 18940  10.906125         -4.548983  0.106367          1.209452
# 18941  14.065103         -2.065450  7.018060         -1.860603
# 18942  -7.468639         -4.515716 -6.628894         -1.242686
# 18943  -0.514081          3.449354 -6.919382         -0.213028
#
#        attacking_short_passing  skill_long_passing
# 0                    -0.796841           -0.419558
# 1                    -1.087135           -1.758301
# 2                    -0.289937            0.294445
# 3                     0.626880           -0.405558
# 4                    -2.430276            3.807389
# ...                        ...                 ...
# 18939                13.010485            0.623597
# 18940                12.359007            1.489099
# 18941                 9.069939            0.850720
# 18942                 6.004688           -3.549547
# 18943                 6.044950            2.068549
#
# [18944 rows x 10 columns]

# %% [markdown]
# An "Explained Variance" of 100.00% in PCA means that all the variation present in the original data is accounted for by the selected principal components. Essentially, none of the data's variability remains unexplained, and you have retained all the important information in a more compact form through PCA.

# %%
explained_variance = pca.explained_variance_ratio_
print(f"Explained Variance: {explained_variance.sum() * 100:.2f}%")
# Out:
# Explained Variance: 100.00%

# %% [markdown]
# ### Standardising the independent variables and inputting the proper column names and formats

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_features=scaler.fit_transform(newX)

# %%
scaled_df = pd.DataFrame(scaled_features, columns=newX.columns)
X= scaled_df

# %%
X
# Out:
#        movement_reactions  mentality_composure   passing  potential  \
# 0                3.243205             0.939973 -0.187350  -2.439628
# 1                2.697325             2.221257  1.125389  -1.157025
# 2                2.380288             2.043449  1.444185  -1.056547
# 3                2.773358             0.992919 -0.562919  -2.751554
# 4                3.266073             0.857540  0.612985  -1.169346
# ...                   ...                  ...       ...        ...
# 18939           -2.441209            -0.738556 -0.157887   1.096358
# 18940           -0.956735            -1.912438 -1.663831   0.220341
# 18941           -0.887799            -1.893705 -0.863508   2.339222
# 18942           -1.092528            -0.027564 -1.882939   0.078405
# 18943           -0.827341            -1.338919 -1.568292   0.705684
#
#        dribbling  power_shot_power    physic  mentality_vision  \
# 0      -0.983606          0.770538 -1.316204         -1.188057
# 1      -1.312707          0.806152 -1.134475         -0.720359
# 2      -0.855018          1.007146 -1.050672          0.966167
# 3      -1.667408          0.524116 -0.892850         -0.730918
# 4       0.446766          1.007370 -1.429719         -0.430336
# ...          ...               ...       ...               ...
# 18939  -0.824703         -2.255453 -0.786334         -1.387771
# 18940   1.653164         -0.752489  0.021572          0.251463
# 18941   2.132006         -0.341665  1.423346         -0.386847
# 18942  -1.132106         -0.746986 -1.344418         -0.258373
# 18943  -0.077925          0.570589 -1.403332         -0.044292
#
#        attacking_short_passing  skill_long_passing
# 0                    -0.179594           -0.147657
# 1                    -0.245022           -0.618809
# 2                    -0.065347            0.103626
# 3                     0.141288           -0.142730
# 4                    -0.547743            1.339956
# ...                        ...                 ...
# 18939                 2.932341            0.219466
# 18940                 2.785509            0.524067
# 18941                 2.044209            0.299398
# 18942                 1.353354           -1.249212
# 18943                 1.362429            0.727996
#
# [18944 rows x 10 columns]

# %% [markdown]
# # 3. Training and Testing the model

# %% [markdown]
# # Training the model with cross validation

# %%
from sklearn.ensemble import VotingRegressor, RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import accuracy_score, f1_score, mean_squared_error, mean_squared_error, mean_absolute_error
from sklearn.model_selection import cross_val_score, RandomizedSearchCV
from xgboost import XGBRegressor

# %%
# Models
models = [
    ('Random Forest', RandomForestRegressor()),
    ('XGBoost', XGBRegressor()),
    ('Gradient Boosting', GradientBoostingRegressor())
]

# Initialize an ensemble model
ensemble_model = VotingRegressor(models)
# Define the number of folds for cross-validation
num_folds = 5

# %% [markdown]
#     The Random Forest model has cross-validation scores that range from approximately -1.914 to -3.707, with a mean score of approximately -2.840.
#     The XGBoost model has cross-validation scores that range from approximately -1.914 to -3.699, with a mean score of approximately -2.842.
#     The Gradient Boosting model has cross-validation scores that range from approximately -1.909 to -3.696, with a mean score of approximately -2.836.
#     In this context, all three models have similar mean scores, indicating comparable performance levels on the dataset. But once again, we choose to work with an ensemble model

# %%
# Iterate through each model
for model_name, model in models:
    # Perform cross-validation
    scores = cross_val_score(ensemble_model, X, y, cv=num_folds)

    print(f"Model: {model_name}")
    print("Cross-Validation Scores:")
    print(scores)
    print(f"Mean Score: {scores.mean()}\n")
# Out:
# Model: Random Forest
# Cross-Validation Scores:
# [-1.91419229 -2.65436638 -3.70676102 -3.0950235  -2.82776623]
# Mean Score: -2.8396218836519336
#
# Model: XGBoost
# Cross-Validation Scores:
# [-1.91447325 -2.66493517 -3.69930669 -3.09867729 -2.8320867 ]
# Mean Score: -2.8418958173848856
#
# Model: Gradient Boosting
# Cross-Validation Scores:
# [-1.90872238 -2.6599034  -3.69551754 -3.09536761 -2.82145117]
# Mean Score: -2.836192420387685

# %%
# Train the ensemble model on the entire dataset
ensemble_model.fit(X, y)
# Out:
# VotingRegressor(estimators=[('Random Forest', RandomForestRegressor()),
#                             ('XGBoost',
#                              XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=None, max_bin=None,
#                                           max_cat_threshold=None,
#                                           max_cat_to_onehot=None,
#                                           max_delta_step=None, max_depth=None,
#                                           max_leaves=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           multi_strategy=None,
#                                           n_estimators=None, n_jobs=None,
#                                           num_parallel_tree=None,
#                                           random_state=None, ...)),
#                             ('Gradient Boosting', GradientBoostingRegressor())])

# %% [markdown]
# # 4. Evaluation

# %% [markdown]
# Random Forest:
#
#     RMSE (Root Mean Squared Error): 4.16 (±1.94) - Measures the average prediction error, with lower values indicating better predictive accuracy.
#     MAE (Mean Absolute Error): 3.59 (±1.76) - Measures the average absolute prediction error, with lower values indicating better predictive accuracy.
#
# XGBoost:
#
#     RMSE (Root Mean Squared Error): 3.58 (±1.56) - Indicates the average prediction error, with lower values suggesting better predictive accuracy.
#     MAE (Mean Absolute Error): 2.98 (±1.39) - Represents the average absolute prediction error, with lower values indicating better predictive accuracy.
#
# Gradient Boosting:
#
#     RMSE (Root Mean Squared Error): 3.97 (±1.72) - Measures the average prediction error, with lower values indicating better predictive accuracy.
#     MAE (Mean Absolute Error): 3.42 (±1.63) - Represents the average absolute prediction error, with lower values indicating better predictive accuracy.
#
# The values in parentheses with the ± indicate the degree of variation or spread in the cross-validation results.

# %%
# Cross-validation and model evaluation (MAE and RMSE)
for name, model in models:
    rmse_scores = np.sqrt(-cross_val_score(model, X, y, scoring='neg_mean_squared_error'))
    mae_scores = -cross_val_score(model, X, y, scoring='neg_mean_absolute_error')
    print(f"{name} - Cross-Validation RMSE: {np.mean(rmse_scores):.2f} (±{np.std(rmse_scores):.2f})")
    print(f"{name} - Cross-Validation MAE: {np.mean(mae_scores):.2f} (±{np.std(mae_scores):.2f})")
# Out:
# Random Forest - Cross-Validation RMSE: 4.16 (±1.94)
# Random Forest - Cross-Validation MAE: 3.59 (±1.76)
# XGBoost - Cross-Validation RMSE: 3.58 (±1.56)
# XGBoost - Cross-Validation MAE: 2.98 (±1.39)
# Gradient Boosting - Cross-Validation RMSE: 3.97 (±1.72)
# Gradient Boosting - Cross-Validation MAE: 3.42 (±1.63)

# %% [markdown]
# Entering the various hyperparameter to be tested for the model

# %%
#Models and their respective hyperparameter grids
models = {
    'Random Forest': (RandomForestRegressor(), {
        'n_estimators': [100, 200, 300],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    }),
    'XGBoost': (XGBRegressor(), {
        'n_estimators': [100, 200, 300],
        'max_depth': [3, 4, 5],
        'learning_rate': [0.01, 0.1, 0.2]
    }),
    'Gradient Boosting': (GradientBoostingRegressor(), {
        'n_estimators': [100, 200, 300],
        'max_depth': [3, 4, 5],
        'learning_rate': [0.01, 0.1, 0.2]
    })
}

# %% [markdown]
# Chosed grid search over randomised search since its more efficient and less memory intensive.

# %%
# Randomized search and model selection
best_models = {}
for name, (model, param_dist) in models.items():
    random_search = RandomizedSearchCV(model, param_distributions=param_dist, n_iter=10, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
    random_search.fit(X, y)
    best_models[name] = random_search.best_estimator_
    print(f"Best {name} Model Parameters: {random_search.best_params_}")
# Out:
# Best Random Forest Model Parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': None}
# Best XGBoost Model Parameters: {'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.2}
# Best Gradient Boosting Model Parameters: {'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.1}

# %%
# Create an ensemble of the best-tuned models
ensemble_regressor = VotingRegressor(estimators=[
    ('Random Forest', best_models['Random Forest']),
    ('XGBoost', best_models['XGBoost']),
    ('Gradient Boosting', best_models['Gradient Boosting'])
])

# %%
# Fit the ensemble regressor to the data
ensemble_regressor.fit(X, y)
# Out:
# VotingRegressor(estimators=[('Random Forest',
#                              RandomForestRegressor(min_samples_leaf=4)),
#                             ('XGBoost',
#                              XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,...
#                                           learning_rate=0.2, max_bin=None,
#                                           max_cat_threshold=None,
#                                           max_cat_to_onehot=None,
#                                           max_delta_step=None, max_depth=4,
#                                           max_leaves=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           multi_strategy=None, n_estimators=300,
#                                           n_jobs=None, num_parallel_tree=None,
#                                           random_state=None, ...)),
#                             ('Gradient Boosting',
#                              GradientBoostingRegressor(max_depth=5,
#                                                        n_estimators=300))])

# %% [markdown]
# # 5. Testing with new data set

# %% [markdown]
# ### Removing useless variables (Those with 30% missing values)

# %% [markdown]
# Dropped excatly the same columns as in the training dataset to ensure standadised data for comparism

# %%
#Loading the datasets to be used (both training and testing)
testing_data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/A 2023/players_22.csv')
data2= testing_data.copy()

# %%
testing_data = testing_data[['movement_reactions','overall', 'mentality_composure', 'passing', 'potential', 'dribbling','power_shot_power','physic','mentality_vision','attacking_short_passing', 'skill_long_passing']]
testing_data
# Out:
#        movement_reactions  overall  mentality_composure  passing  potential  \
# 0                      94       93                   96     91.0         93
# 1                      93       92                   88     79.0         92
# 2                      94       91                   95     80.0         91
# 3                      89       91                   93     86.0         91
# 4                      91       91                   89     93.0         91
# ...                   ...      ...                  ...      ...        ...
# 19234                  53       47                   37     46.0         52
# 19235                  49       47                   47     50.0         59
# 19236                  46       47                   36     45.0         55
# 19237                  48       47                   47     36.0         60
# 19238                  54       47                   36     45.0         60
#
#        dribbling  power_shot_power  physic  mentality_vision  \
# 0           95.0                86    65.0                95
# 1           86.0                90    82.0                81
# 2           88.0                94    75.0                76
# 3           94.0                80    63.0                90
# 4           88.0                91    78.0                94
# ...          ...               ...     ...               ...
# 19234       48.0                46    49.0                43
# 19235       46.0                49    51.0                49
# 19236       49.0                50    52.0                46
# 19237       48.0                48    42.0                40
# 19238       48.0                50    48.0                46
#
#        attacking_short_passing  skill_long_passing
# 0                           91                  91
# 1                           85                  70
# 2                           80                  77
# 3                           86                  81
# 4                           94                  93
# ...                        ...                 ...
# 19234                       50                  48
# 19235                       51                  50
# 19236                       49                  49
# 19237                       38                  33
# 19238                       50                  49
#
# [19239 rows x 11 columns]

# %%
threshold = 0.30 *len(testing_data)

# %%
testing_data = testing_data.dropna(thresh=threshold, axis =1)

# %% [markdown]
# ### Splitting numerical and categorical

# %%
Ytest = testing_data['overall']
testing_data.drop('overall', axis=1,inplace=True)

# %%
numerical_col = testing_data.select_dtypes(include=['int64', 'float64']).columns
categorical_col = testing_data.select_dtypes(include=['object']).columns

# %%
categorical_var_test = testing_data[categorical_col]
numerical_var_test = testing_data[numerical_col]

# %%
numerical_var_test
# Out:
#        movement_reactions  mentality_composure  passing  potential  dribbling  \
# 0                      94                   96     91.0         93       95.0
# 1                      93                   88     79.0         92       86.0
# 2                      94                   95     80.0         91       88.0
# 3                      89                   93     86.0         91       94.0
# 4                      91                   89     93.0         91       88.0
# ...                   ...                  ...      ...        ...        ...
# 19234                  53                   37     46.0         52       48.0
# 19235                  49                   47     50.0         59       46.0
# 19236                  46                   36     45.0         55       49.0
# 19237                  48                   47     36.0         60       48.0
# 19238                  54                   36     45.0         60       48.0
#
#        power_shot_power  physic  mentality_vision  attacking_short_passing  \
# 0                    86    65.0                95                       91
# 1                    90    82.0                81                       85
# 2                    94    75.0                76                       80
# 3                    80    63.0                90                       86
# 4                    91    78.0                94                       94
# ...                 ...     ...               ...                      ...
# 19234                46    49.0                43                       50
# 19235                49    51.0                49                       51
# 19236                50    52.0                46                       49
# 19237                48    42.0                40                       38
# 19238                50    48.0                46                       50
#
#        skill_long_passing
# 0                      91
# 1                      70
# 2                      77
# 3                      81
# 4                      93
# ...                   ...
# 19234                  48
# 19235                  50
# 19236                  49
# 19237                  33
# 19238                  49
#
# [19239 rows x 10 columns]

# %% [markdown]
# ### KNN imputation of numerical variables

# %%
knn_imputer = KNNImputer(n_neighbors=8)
numerical_var_imputed_2 = knn_imputer.fit_transform(numerical_var_test)
numerical_columns = list(numerical_var_test.columns)
numerical_var_imputed_2 = pd.DataFrame(numerical_var_imputed_2, columns=numerical_col)

# %% [markdown]
# ### Joining back the clean numerical and categorical datasets

# %%
Xtest = numerical_var_imputed_2
Xtest
# Out:
#        movement_reactions  mentality_composure  passing  potential  dribbling  \
# 0                    94.0                 96.0     91.0       93.0       95.0
# 1                    93.0                 88.0     79.0       92.0       86.0
# 2                    94.0                 95.0     80.0       91.0       88.0
# 3                    89.0                 93.0     86.0       91.0       94.0
# 4                    91.0                 89.0     93.0       91.0       88.0
# ...                   ...                  ...      ...        ...        ...
# 19234                53.0                 37.0     46.0       52.0       48.0
# 19235                49.0                 47.0     50.0       59.0       46.0
# 19236                46.0                 36.0     45.0       55.0       49.0
# 19237                48.0                 47.0     36.0       60.0       48.0
# 19238                54.0                 36.0     45.0       60.0       48.0
#
#        power_shot_power  physic  mentality_vision  attacking_short_passing  \
# 0                  86.0    65.0              95.0                     91.0
# 1                  90.0    82.0              81.0                     85.0
# 2                  94.0    75.0              76.0                     80.0
# 3                  80.0    63.0              90.0                     86.0
# 4                  91.0    78.0              94.0                     94.0
# ...                 ...     ...               ...                      ...
# 19234              46.0    49.0              43.0                     50.0
# 19235              49.0    51.0              49.0                     51.0
# 19236              50.0    52.0              46.0                     49.0
# 19237              48.0    42.0              40.0                     38.0
# 19238              50.0    48.0              46.0                     50.0
#
#        skill_long_passing
# 0                    91.0
# 1                    70.0
# 2                    77.0
# 3                    81.0
# 4                    93.0
# ...                   ...
# 19234                48.0
# 19235                50.0
# 19236                49.0
# 19237                33.0
# 19238                49.0
#
# [19239 rows x 10 columns]

# %% [markdown]
# Standardising the independent variables

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_features=scaler.fit_transform(Xtest)

# %%
columns_order = ['movement_reactions', 'mentality_composure', 'passing', 'potential', 'dribbling','power_shot_power','physic','mentality_vision','attacking_short_passing', 'skill_long_passing']

extracted_columns = scaled_df[columns_order]

# 2. Create a new DataFrame with the extracted columns
newX = pd.DataFrame(scaled_features, columns=columns_order)

# %%
newX
# Out:
#        movement_reactions  mentality_composure   passing  potential  \
# 0                3.599846             3.131025  2.997388   3.601780
# 1                3.489252             2.473077  2.004597   3.437470
# 2                3.599846             3.048782  2.087330   3.273160
# 3                3.046874             2.884295  2.583725   3.273160
# 4                3.268063             2.555321  3.162854   3.273160
# ...                   ...                  ...       ...        ...
# 19234           -0.934526            -1.721343 -0.725578  -3.134932
# 19235           -1.376903            -0.898908 -0.394648  -1.984762
# 19236           -1.708687            -1.803587 -0.808311  -2.642002
# 19237           -1.487498            -0.898908 -1.552904  -1.820452
# 19238           -0.823931            -1.803587 -0.808311  -1.820452
#
#        dribbling  power_shot_power    physic  mentality_vision  \
# 0       3.063069          2.139433  0.091475          3.006228
# 1       2.263961          2.442649  1.871337          1.980597
# 2       2.441541          2.745866  1.138453          1.614300
# 3       2.974279          1.684607 -0.117921          2.639931
# 4       2.441541          2.518454  1.452546          2.932969
# ...          ...               ...       ...               ...
# 19234  -1.110051         -0.892735 -1.583691         -0.803260
# 19235  -1.287631         -0.665323 -1.374295         -0.363704
# 19236  -1.021262         -0.589519 -1.269597         -0.583482
# 19237  -1.110051         -0.741127 -2.316575         -1.023038
# 19238  -1.110051         -0.589519 -1.688388         -0.583482
#
#        attacking_short_passing  skill_long_passing
# 0                     2.217457            2.524112
# 1                     1.803392            1.126551
# 2                     1.458338            1.592404
# 3                     1.872403            1.858606
# 4                     2.424490            2.657213
# ...                        ...                 ...
# 19234                -0.611986           -0.337561
# 19235                -0.542976           -0.204460
# 19236                -0.680997           -0.271010
# 19237                -1.440116           -1.335819
# 19238                -0.611986           -0.271010
#
# [19239 rows x 10 columns]

# %% [markdown]
# Evaluate model using player_22 test data

# %% [markdown]
#     Mean Absolute Error (MAE): It measures the average absolute difference between the predicted and actual values. In this case, the MAE is approximately 3.855, which indicates, on average, the model's predictions are off by about 3.855 units.
#
#     Mean Squared Error (MSE): It calculates the average of the squared differences between predicted and actual values. The MSE here is approximately 24.276, which is a measure of the average squared prediction error.
#
#     Root Mean Squared Error (RMSE): This is the square root of the MSE and is often used as a more interpretable measure of prediction error. The RMSE is approximately 4.927, indicating the average prediction error is roughly 4.927 units.
#
#     R-squared (R2): This metric measures the proportion of the variance in the dependent variable (the one being predicted) that is explained by the independent variables (the predictors) in the model. An R-squared of approximately 0.487 suggests that the model explains about 48.7% of the variance in the data, which means it has some level of predictive power but may not capture all the variability.

# %%
from sklearn.metrics import r2_score
predictions = ensemble_regressor.predict(newX)
mae = mean_absolute_error(Ytest, predictions)
mse = mean_squared_error(Ytest, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(Ytest, predictions)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Absolute Error (MAE): 3.8547046930582103
# Mean Squared Error (MSE): 24.27640942856538
# Root Mean Squared Error (RMSE): 4.927109642433927
# R-squared (R2): 0.4871375245312517

# %% [markdown]
# # 6. Deployment

# %%
'''#Saving the model in a pickle file
import pickle
filename = 'trained_model.pkl'
pickle.dump(ensemble_regressor, open(filename,'wb'))'''
import joblib

# Saving the model
joblib.dump(ensemble_regressor, 'trained_model.pkl')
# Out:
# ['trained_model.pkl']
